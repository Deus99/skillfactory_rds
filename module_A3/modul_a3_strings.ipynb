# %% [markdown]
# # Модуль А3. Строковые величины.

# %% [markdown]
# ## 3.2 Индексы и срезы

# %% [markdown]
# ### Задача 3.2.1  Срез
# Используя срез, напишите код, с помощью которого можно извлечь из строки proverb слово "Программист".
# Код должен быть написан в одну строку без пробелов. Используйте положительные индексы. Оба индекса среза задайте в явном виде.

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
#word_set=proverb.split(' ')
#print (len(word_set[0]))
#word_set[:]   
print (proverb[0:11])
# Out:
# Программист

# %% [markdown]
# ### Задача 3.2.2 Извлекаем из середины слова срез
# Напишите код, с помощью которого можно извлечь из строки proverb слово "кофе".
# Код должен быть написан в одну строку без пробелов. Используйте отрицательные индексы. Оба индекса среза задайте в явном виде.

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
word_f='устройств'
for i in range(0,len(proverb),1):
    if proverb[i-len(word_f):i]==word_f:
        letter_start=i
print(proverb[letter_start-len(word_f):letter_start])
print(letter_start-len(word_f),':',letter_start)
# Out:
# устройств
# 19 : 28

# %% [markdown]
# ### 3.2.4 Шифровальщик
# Напишите программу, которая "зашифровывает" текст, хранящийся в переменной proverb, меняя местами символы, стоящие на нечётных и чётных позициях. Результат шифрования нужно вывести на экран с помощью функции print
# Используйте переменную proverb для хранения исходной фразы и переменную new_proverb для хранения "зашифрованной" фразы.
# Пример: после шифровки начало фразы должно выглядеть так: рПгоарммсиыт

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
new_proverb=str()
for i in range(0,len(proverb),2):
    new_proverb=new_proverb+new_proverb.join(proverb[i+1])
    new_proverb=new_proverb+new_proverb.join(proverb[i])
print (new_proverb)
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д
# 58 58

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
new_proverb=''
for i in range(0,len(proverb),2):
    new_proverb = proverb[i:i+2][::-1]
    print (new_proverb,end = '')
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %%
proverb = 'Программисты - это устройства, преобразующие кофеин в код.'
new_proverb=''
for letter in proverb[1::2]:
    new_proverb=new_proverb+letter+proverb[len(new_proverb)]
print(new_proverb)
# Out:
# рПгоарммсиыт- э оту тсорсйвт,ап ербоарузщюеик фоие н вок.д

# %% [markdown]
# ### 3.2.5 Палиндром
# Некоторые слова одинаково читаются как слева направо, так и справа налево. Такие слова называются палиндромами.
#
# Напишите программу, которая оценивает слово, заданное в перееменной basic_word, и выдаёт сообщение: 'Слово "..." является палиндромом' в случае, если заданное слово одинаково читается слева направо и справа налево, и сообщение: 'Слово "..." - это не палиндром' в противном случае.
#
# Вместо многоточия в каждой из фраз должно стоять слово, заданное в переменной basic_word. Обратите внимание на то, что заданное слово должно быть взято в кавычки.
#
# При написании кода используйте две обязательные переменные: basic_word —для хранения заданного слова и inverted_word— для хранения перевёрнутого варианта заданного слова. Во время проверки кода на платформе используйте значение basic_word = 'программирование'.

# %%
basic_word='программирование'
#basic_word='программаргорп'
inverted_word=''
for letter in basic_word[-1::-1]:
    inverted_word=inverted_word+letter
if basic_word==inverted_word:
    print ('Слово "'+basic_word+'" является палиндромом')
else:
    print ('Слово "'+basic_word+'" - это не палиндром')
# Out:
# Слово "программирование" - это не палиндром

# %% [markdown]
# ## 3.3 Поиск подстроки в строке

# %% [markdown]
# ### 3.3.3 Доменное имя в e-mail
# Дана переменная email, содержащая произвольный адрес электронной почты. Напишите универсальный код, с помощью которого можно извлечь из этого адреса адрес домена.
#
# Пояснения:
# Код должен быть написан в одну строку без пробелов.
# Не используйте никаких дополнительных имён переменных, кроме переменной email.
# Не присваивайте результат извлечения никакой другой переменной.
# Используйте апострофы (не кавычки!) для обозначения символа, позицию которого нужно найти в строке.

# %%
email='vi@vifoto.ru'
#sobaka=email.find('@')
email=email[email.find('@')+1:]

print(email)
# Out:
# vifoto.ru

# %% [markdown]
# ### 3.3.4 Подсчет дробной части.
# Дано вещественное число. Напишите программу, которая считает сумму цифр дробной части числа. Результат вычислений нужно вывести на экран с помощью функции print
#
# Используйте переменную number = 56.257 для хранения заданного числа и не меняйте её в процессе выполнения кода.

# %%
number=56.257
s=0
for cif in (str(number).split('.')[1]):
    s+=int(cif)
    
print(s)
# Out:
# 14

# %% [markdown]
# ### 3.3.5 Словарь из списка e-mail
# Дан список emails_list, содержащий электронные адреса десяти человек. Вам нужно написать программу, которая создаёт словарь emails_dict .Ключами словаря должны быть адреса доменов, а значениями — количество электронных адресов из списка emails_list, зарегистрированных на каждом домене.

# %%
emails_list = ['vasya@mail.ru', 
          'akakiy@yandex.ru', 
          'spyderman@yandex.ru', 
          'XFiles@gmail.com', 
          'hello@mail.ru', 
          'noname@gmail.com', 
          'DonaldTrump@mail.ru', 
          'a768#af@yandex.ru', 
          'Ivan_Ivanovich@yandex.ru', 
          'thebestmail@yandex.ru']
#ПОГНАЛИ!

import collections #библиотека со счетчиком

#Создаем список только с доменами
email_temp=[]
for email in emails_list:
    email_temp.append(email[email.find('@')+1:])

#считаем домен
domen_kolvo=collections.Counter() 
for domen in email_temp:
    domen_kolvo[domen]+=1

emails_dict=dict(domen_kolvo)
# Out:
# {'mail.ru': 3, 'yandex.ru': 5, 'gmail.com': 2}

# %% [markdown]
# ## 3.4 Преобразование строк

# %%
string = 'Интернет-открытки - это лучшее средство для мужчины сказать женщине о своих чувствах прямо в глаза.'
secret = string[24:30]
print(secret)
# Out:
# лучшее

# %% [markdown]
# ### Задача 3.4.4 Замена символов
# Дана переменная string, в которой нужно заменить все знаки препинания на смайлики (':)'). Знаками препинания считайте символы: точка, запятая, двоеточие, тире (дефис), восклицательный и вопросительный знаки. Значение переменной string должно измениться в процессе выполнения программы.
#
# Решите задачу для string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'
#
# Пример:
# исходное значение переменной: string = 'Привет, Андрей!'
# итоговое значение переменной: string = 'Привет:) Андрей:)'

# %%
string = 'Тяжёлая интернет-зависимость - это когда ты выходишь из интернета, а он из тебя нет.'
for index in ':.,-!?': #НАЧИНАТЬ С ДВОЕТОЧИЯ, Т,К ПОТОМ ОНО ЗАМЕНЯЕТСЯ!!!
    string=string.replace(index,':)')

print(string)
# Out:
# Тяжёлая интернет:)зависимость :) это когда ты выходишь из интернета:) а он из тебя нет:)

# %% [markdown]
# ### Задача 3.4.5 Вывод гласных и согласных букв
# Дана переменная name, в которой хранится имя пользователя, записанное русскими буквами. Напишите программу, которая перебирает имя по буквам и для каждой буквы выводит сообщение: "... - гласная буква" или "... - согласная буква", где вместо многоточия нужно подставить букву из имени пользователя.
#
# Значение переменной name не должно меняться в ходе выполнения программы. В сообщениях, выводимых на экран, буквы из имени пользователя должны выводиться в том же регистре, в котором они присутствуют в переменной name.
#
# Решите задачу для name = 'Севастиан'
#
# Пример работы программы для имени Анна:
# А - гласная буква
# н - согласная буква
# н - согласная буква
# а - гласная буква
# Подсказка: чтобы избавить себя от необходимости выполнять проверку сложного составного условия, вы можете создать два списка с буквами: в одном хранить гласные буквы, а в другом — согласные.

# %%
name = 'Севастиан'

glasn='уеыаоэяиюё'

for i in range(len(name)):
    if name.lower()[i] in glasn:
        print(name[i]+' - гласная буква') 
    else:
        print(name[i]+' - согласная буква')
# Out:
# С - согласная буква
# е - гласная буква
# в - согласная буква
# а - гласная буква
# с - согласная буква
# т - согласная буква
# и - гласная буква
# а - гласная буква
# н - согласная буква

# %% [markdown]
# ## 3.6 Модуль re

# %%
import re 
pattern = re.compile('[А-Я][а-я]*\W')

# %%
string = '!!! Йо! Учиться, учиться и учиться! Вперёд! Только вперёд!' 
pattern.match(string)

# %%
pattern.search(string)
# Out:
# <re.Match object; span=(4, 7), match='Йо!'>

# %%
pattern.findall(string)
# Out:
# ['Йо!', 'Учиться,', 'Только ']

# %%
text = 'Разработка языка Python была начата в конце 1980-х годов сотрудником голландского института CWI Гвидо ван Россумом. Для распределённой ОС Amoeba требовался расширяемый скриптовый язык, и Гвидо начал писать Python на досуге, позаимствовав некоторые наработки для языка ABC (Гвидо участвовал в разработке этого языка, ориентированного на обучение программированию). В феврале 1991 года Гвидо опубликовал исходный текст в группе новостей alt.sources. Название языка произошло вовсе не от вида пресмыкающихся. Автор назвал язык в честь популярного британского комедийного телешоу 1970-х "Летающий цирк Монти Пайтона".'

# %%
text_f=re.compile('\d+')
text_f.search(text)
# Out:
# <re.Match object; span=(44, 48), match='1980'>

# %%
text_f=re.compile('[A-Za-z]+')
text_f.findall(text)
# Out:
# ['Python', 'CWI', 'Amoeba', 'Python', 'ABC', 'alt', 'sources']

# %%
text_f=re.compile('[А-Яа-я]+ка')
text_f.findall(text)
# Out:
# ['Разработка', 'языка', 'языка', 'языка', 'языка', 'пресмыка']

# %% [markdown]
# ### 3.6.4  Подсчет слов с буквами "аи"
# Используя возможности модуля re определите, сколько слов, содержащих русские буквы "а" и "и", разделённые любыми двумя буквами, содержится в переменной text. Введите количество слов в поле для ответа.

# %%
text_f=re.compile('\S*[а]\w\w[и]\w*')
a=text_f.findall(text)
print(a)
print(len(a))
# Out:
# ['расширяемый', 'программированию', 'пресмыкающихся', '"Летающий']
# 4

# %% [markdown]
# ### 3.6.5 Подсчет с пробелом.
# Используя возможности модуля re, определите количество пар слов, в которых первое слово заканчивается на гласную русскую букву, второе — начинается на согласную (также русскую). Введите количество найденных пар слов в поле для ответа.
#
# Во время подсчёта не учитывайте регистр букв (т.е. при подсчёте должны учитываться как вариант: "...а П..." , так и вариант: "...а п..." ). Предлоги и союзы считайте полноправными словами, даже если они состоят из одной буквы.
#
# Если между словами имеется знак препинания, считайте, что эти два слова НЕ удовлетворяют критерию поиска (т.е. вариант: "...а, П..." НЕ должен учитываться при подсчёте).

# %%
text_f=re.compile('\S*[ёуеаоэяиюыЁУЕАОЫИЮЭЯ]\s[ЙЦКНГШЩЗХФВПРЛДЖЭЧСМТБйцкнгшщзхфвпрлджчсмтбьъ]')
a=text_f.findall(text)
print(a)
print(len(a))
# Out:
# ['была н', 'ачата в', 'Гвидо в', 'Для р', 'требовался р', 'и Г', 'видо н', 'на д', 'некоторые н', 'аработки д', 'ориентированного н', 'обучение п', 'года Г', 'группе н', 'языка п', 'роизошло в', 'овсе н', 'вида п', 'популярного б', 'ританского к', 'омедийного т', 'Монти П']
# 22

# %% [markdown]
# ## 3.7 Построчное чтение файла.

# %%
f = open('StudentsPerformance.csv')

# %%
for line in f:
         print(line)
f.close()
# Out:
# "gender","race/ethnicity","parental level of education","lunch","test preparation course","math score","reading score","writing score"
#
# "female","group B","bachelor's degree","standard","none","72","72","74"
#
# "female","group C","some college","standard","completed","69","90","88"
#
# "female","group B","master's degree","standard","none","90","95","93"
#
# "male","group A","associate's degree","free/reduced","none","47","57","44"
#
# "male","group C","some college","standard","none","76","78","75"
#
# "female","group B","associate's degree","standard","none","71","83","78"
#
# "female","group B","some college","standard","completed","88","95","92"
#
# "male","group B","some college","free/reduced","none","40","43","39"
#
# "male","group D","high school","free/reduced","completed","64","64","67"
#
# "female","group B","high school","free/reduced","none","38","60","50"
#
# "male","group C","associate's degree","standard","none","58","54","52"
#
# ...

# %%
f = open('StudentsPerformance.csv')
males = 0
females = 0
for line in f:
    info = line.split(',')
    gender = info[0][1:-1]
    if gender == 'female':
        females += 1
    elif gender == 'male':
        males +=1
print('Мальчиков: {}, девочек: {}'.format(males, females))
# Out:
# Мальчиков: 482, девочек: 518

# %% [markdown]
# ### 3.7.1 Задача 1. Считаем дипломы
# У скольких абитуриентов родители имеют диплом бакалавра (bachelor's degree)?
#
# Введите ответ в виде целого числа. При написании кода обратите внимание на использование кавычек/апострофов

# %%
f = open('StudentsPerformance.csv')
diploms=0
for line in f:
    info = line.split(',')
    par_obraz = info[2][1:-1]
    if par_obraz == "bachelor's degree":
        diploms+=1
print('Родители-бакалавры',diploms)
# Out:
# Родители-бакалавры 118

# %% [markdown]
# ### 3.7.2 Считаем различные варианты образований.
# Сколько разных вариантов значений встречается в столбце "parental level of education"?
# Введите ответ в виде целого числа.
# Подсказка 1: для хранения уникальных вариантов вы можете использовать список.
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.csv')
#список для хранения разных вариантов уровней образования
parental_levels=set()


for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        parental_levels.add(info[2][1:-1])

print (len(parental_levels))
# Out:
# 6

# %% [markdown]
# ### 3.7.3 Считаем количество жрущих
# Сколько процентов абитуриентов полноценно пообедали перед экзаменом? (У скольких процентов абитуриентов значение столбца "lunch" = "standard").
#
# Ответ введите в виде десятичной дроби. Знак процента вводить не нужно.

# %%
f = open('StudentsPerformance.csv')
obed=0
students=0
for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        students+=1
        if info[3][1:-1]=='standard':
            obed+=1
print(obed,stud)
# Out:
# 645 1000

# %% [markdown]
# ### 3.7.4 Этническая группа
# Сколько абитуриентов относится к этнической группе "group C"?
#
# Введите ответ в виде целого числа.

# %%
f = open('StudentsPerformance.csv')

students=int(0)
for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
#        students+=1
        if info[1][-2:-1]=='C':
            students+=1
print(students)
# Out:
# 319

# %% [markdown]
# ### 3.7.5 Количество этнических групп
# Сколько разных этнических групп встречается в файле?
#
# Введите ответ в виде целого числа.
#
# Подсказка 1: для хранения уникальных вариантов Вы можете использовать список.
#
# Подсказка 2: не забудьте, что первая строка файла содержит заголовки столбцов и не должна учитываться при обработке

# %%
f = open('StudentsPerformance.csv')

etnic_grups=set()
for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        etnic_grups.add(info[1][1:-1])
print(len(etnic_grups))
# Out:
# 5

# %% [markdown]
# ## 3.8 Преобразование файла в список

# %% [markdown]
# ### 3.8.1  Средний балл
# Вычислите средний балл абитуриентов на экзамене по чтению (reading score).
#
# Введите ответ в виде одного числа. Не округляйте полученное значение.

# %%
import re
pattern = re.compile('\d+')

f = open('StudentsPerformance.csv')
reading_marks=[]

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        if pattern.search(info[6])!=None:
            reading_marks.append(int(pattern.search(info[6])[0]))
        else:
            reading_marks.append(int(info[6][-1:1]))

reading_MS =sum(reading_marks)/len(reading_marks)

print ('Средняя оценка по чтению', reading_MS)
# Out:
# Средняя оценка по чтению 69.169

# %% [markdown]
# ### 3.8.3 Средняя оценка и количество участников
# Сколько абитуриентов получили на экзамене по чтению (reading score) оценку ниже среднего?
#
# Введите количество абитуриентов в окно для ответа.

# %%
counter=0
for score in reading_marks:
    if score < reading_MS:
        counter+=1
print (counter)
# Out:
# 487

# %% [markdown]
# ### 3.8.4 Средняя оценка по чтению у двеочек
# Какой средний балл экзамене по чтению (reading score) получили девочки?
# Ответ округлите до трёх знаков после запятой.

# %%
import re
pattern = re.compile('\d+')

f = open('StudentsPerformance.csv')
reading_marks=[]

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        if info[0][1:-1]=='female':
            if pattern.search(info[6])!=None:
                reading_marks.append(int(pattern.search(info[6])[0]))
            else:
                reading_marks.append(int(info[6][-1:1]))

reading_MS =sum(reading_marks)/len(reading_marks)

print ('Средняя оценка по чтению', reading_MS)
# Out:
# Средняя оценка по чтению 72.60810810810811

# %% [markdown]
# ### 3.8.5 Количество отличников
# Сколько абитуриентов получили на экзамене по письму (writing score) оценку выше 90?
# Введите количество абитуриентов в окно для ответа.
#
# Сколько процентов абитуриентов, получивших на экзамене по письму (writing score) оценку более 90, хорошо пообедали перед экзаменом (lunch = standard)?
#
# Введите ответ в виде дробного числа без знака процента, округлив до первого знака после запятой.

# %%
import re
pattern = re.compile('\d+')

botany=0
botany_obed=0
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        if pattern.search(info[7])!=None:
            mark=int(pattern.search(info[7])[0])
        else:
            mark=int(info[7][-1:1])
        if mark>90 and info[3][1:-1]=='standard':
            botany_obed+=1
        if mark>90:
            botany+=1
                

print ('Ботаны по письмус хорошим обедом', botany_obed/botany)
# Out:
# Ботаны по письму 0.8676470588235294

# %% [markdown]
# ## 3.9 Преобразование файла в словарь
#
# ### 3.9.1 Мальчики и обед
# ### 3.9.2 Мальчики и курсы
# ### 3.9.3 Девочки и родители
# Создаем общий словарь. Мальчики/девочки --> Питание , Курсы, образование родителей для решения первых трех задач.

# %%
students={}
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        gender=info[0][1:-1]  #Считываем данные о поле, обеде и курсах, образовании родителей
        math=info[5][1:-1]
        kurs=info[4][1:-1]
        parents_o=info[2][1:-1]
        if gender in students:  # Если ключ с полом создан, заполняем другие ключи вложенного словарь
            if lunch in students[gender]['lunch']:
                students[gender]['lunch'][lunch]+=1 
            else:
                students[gender]['lunch'][lunch]=1
            if kurs in students[gender]['kurs']:
                students[gender]['kurs'][kurs]+=1
            else:
                students[gender]['kurs'][kurs]=1
            if parents_o in students[gender]['parents_o']:
                students[gender]['parents_o'][parents_o]+=1
            else:
                students[gender]['parents_o'][parents_o]=1
        else:
            students[gender]={} #создаем вложенный словарь
            students[gender]['lunch']={}
            students[gender]['lunch'][lunch]=1
            students[gender]['kurs']={}
            students[gender]['kurs'][kurs]=1
            students[gender]['parents_o']={}
            students[gender]['parents_o'][parents_o]=1
            
            
            
            
print (students['male']['lunch'])

print (students['male']['kurs'])

print (students['female']['parents_o'])
# Out:
# {'free/reduced': 166, 'standard': 316}
# {'none': 308, 'completed': 174}
# {"bachelor's degree": 63, 'some college': 118, "master's degree": 36, "associate's degree": 116, 'high school': 94, 'some high school': 91}

# %% [markdown]
# ### 3.9.4 Этнические группы и курсы
# Сколько абитуриентов, относящихся к этнической группе С, закончили подготовительные курсы?
#
# Ответ введите в виде одного числа.

# %%
students={}
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        group=info[1][1:-1]  #Считываем данные о поле, обеде и курсах, образовании родителей
        kurs=info[4][1:-1]
        if group in students:  # Если ключ с полом создан, заполняем другие ключи вложенного словарь
            if kurs in students[group]['kurs']:
                students[group]['kurs'][kurs]+=1
            else:
                students[group]['kurs'][kurs]=1
        else:
             #создаем вложенный словарь
            students[group]={}
            students[group]['kurs']={}
            students[group]['kurs'][kurs]=1
            
            
            
            
print (students['group C'])
# Out:
# {'kurs': {'completed': 117, 'none': 202}}

# %% [markdown]
# ### 3.9.5 Девочки и баллы по математике
# Сколько девочек, родители которых имеют степень магистра, набрали по математике больше 90 баллов?

# %%
students={}
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        gender=info[0][1:-1]  #Считываем данные о поле, обеде и курсах, образовании родителей
        math=info[5][1:-1]
        parents_o=info[2][1:-1]
        if gender in students:  # Если ключ с полом создан, заполняем другие ключи вложенного словарь
            if parents_o in students[gender]['parents_o']:
                students[gender]['parents_o'][parents_o].append(int(math))
            else:
                students[gender]['parents_o'][parents_o]=[]
                students[gender]['parents_o'][parents_o].append(int(math))
        else:
            students[gender]={} #создаем вложенный словарь
            students[gender]['parents_o']={}
            students[gender]['parents_o'][parents_o]=[]
            students[gender]['parents_o'][parents_o].append(int(math))
            
mark=0
for i in students['female']['parents_o']['master\'s degree']:
    if i>90:
        mark+=1
            
            
print (students['female']['parents_o']['master\'s degree'])
print (mark)
# Out:
# [90, 50, 62, 56, 62, 87, 81, 58, 81, 52, 69, 45, 65, 77, 85, 70, 47, 55, 74, 40, 77, 64, 61, 53, 54, 40, 94, 77, 52, 54, 81, 50, 73, 78, 92, 88]
# 2

# %%
string='asdfgasgasdfg'
print(string[-1::-1])
# Out:
# gfdsagsagfdsa

# %% [markdown]
# ### 3.10  Средняя оценка
# Какой средний балл, полученный мальчиками на экзамене по чтению? Ответ округлите до трёх цифр после запятой.

# %%
students={}
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        gender=info[0][1:-1]  #Считываем данные о поле, обеде и курсах, образовании родителей
        math=int(info[5][1:-1])
        reading=int(info[6][1:-1])
        writing=int(info[7][1:-2])
        lunch=info[3][1:-1]
        if gender in students:  # Если ключ с полом создан, заполняем другие ключи вложенного словарь
            if lunch in students[gender]['lunch']:
                students[gender]['lunch'][lunch]['math_s'].append(math)
                students[gender]['lunch'][lunch]['writing_s'].append(writing)
                students[gender]['lunch'][lunch]['reading_s'].append(reading)
            else:
                students[gender]['lunch'][lunch]={}
                students[gender]['lunch'][lunch]['math_s']=[]
                students[gender]['lunch'][lunch]['writing_s']=[]
                students[gender]['lunch'][lunch]['reading_s']=[]
                students[gender]['lunch'][lunch]['math_s'].append(math)
                students[gender]['lunch'][lunch]['writing_s'].append(writing)
                students[gender]['lunch'][lunch]['reading_s'].append(reading)
        else:
            students[gender]={}
            students[gender]['lunch']={}
            students[gender]['lunch'][lunch]={}
            students[gender]['lunch'][lunch]['math_s']=[]
            students[gender]['lunch'][lunch]['writing_s']=[]
            students[gender]['lunch'][lunch]['reading_s']=[]
            students[gender]['lunch'][lunch]['math_s'].append(math)
            students[gender]['lunch'][lunch]['writing_s'].append(writing)
            students[gender]['lunch'][lunch]['reading_s'].append(reading)    

            
#Задача 3.10.8 Какой средний балл, полученный мальчиками на экзамене по чтению? Ответ округлите до трёх цифр после запятой.            
score_m_reading=0
count=0
for obed in students['male']['lunch'].keys():
    for score in students['male']['lunch'][obed]['reading_s']: 
        score_m_reading+=score
        count+=1
        
print ('Средний балл мальчиков на экзамене по чтению',score_m_reading/count)


math_marks_all=[]
for gender in students.keys():
    for obed in students[gender]['lunch'].keys():
        for m_score in students[gender]['lunch'][obed]['math_s']:
            math_marks_all.append(m_score)


r_summ=0
r_count=0
for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        math2=int(info[5][1:-1])
        print(math2)
        reading=int(info[6][1:-1])
        if math2==max(math_marks_all):
            r_summ+=reading
            r_count+=1
#print (r_summ/r_count)
# Out:
# Средний балл мальчиков на экзамене по чтению 65.47302904564316

# %%
#Задача 3.10.9 Какой средний балл на экзамене по чтению набрали ученики, 
#набравшие максимальный балл на экзамене по математике? Ответ округлите до трёх цифр после запятой.

students={}
f = open('StudentsPerformance.csv')
r_summ=0
r_count=0
for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        math2=int(info[5][1:-1])
        reading=int(info[6][1:-1])
        if math2==100:
            r_summ+=reading
            r_count+=1
print (r_summ/r_count)
# Out:
# 97.85714285714286

# %% [markdown]
# ### 3.10.11 Средний балл по письму и обед
# Какой средний балл на экзамене по письму набрали ученики, которые плохо победали перед экзаменом (lunch = free/reduced)? Ответ округлите до двух цифр после запятой.
#   нет ответа

# %%
students={}
f = open('StudentsPerformance.csv')

for line in f:
    info=line.split(',')
    if info[0][1:-1]=='male' or info[0][1:-1]=='female':
        gender=info[0][1:-1]  #Считываем данные о поле, обеде и курсах, образовании родителей
        math=int(info[5][1:-1])
        reading=int(info[6][1:-1])
        writing=int(info[7][1:-2])
        lunch=info[3][1:-1]
        if gender in students:  # Если ключ с полом создан, заполняем другие ключи вложенного словарь
            if lunch in students[gender]['lunch']:
                students[gender]['lunch'][lunch]['math_s'].append(math)
                students[gender]['lunch'][lunch]['writing_s'].append(writing)
                students[gender]['lunch'][lunch]['reading_s'].append(reading)
            else:
                students[gender]['lunch'][lunch]={}
                students[gender]['lunch'][lunch]['math_s']=[]
                students[gender]['lunch'][lunch]['writing_s']=[]
                students[gender]['lunch'][lunch]['reading_s']=[]
                students[gender]['lunch'][lunch]['math_s'].append(math)
                students[gender]['lunch'][lunch]['writing_s'].append(writing)
                students[gender]['lunch'][lunch]['reading_s'].append(reading)
        else:
            students[gender]={}
            students[gender]['lunch']={}
            students[gender]['lunch'][lunch]={}
            students[gender]['lunch'][lunch]['math_s']=[]
            students[gender]['lunch'][lunch]['writing_s']=[]
            students[gender]['lunch'][lunch]['reading_s']=[]
            students[gender]['lunch'][lunch]['math_s'].append(math)
            students[gender]['lunch'][lunch]['writing_s'].append(writing)
            students[gender]['lunch'][lunch]['reading_s'].append(reading)    

score_m_writing=0
count=0
for stu in students.keys():
    for score in students[stu]['lunch']['free/reduced']['writing_s']: 
        score_m_writing+=score
        count+=1
print (score_m_writing/count)
# Out:
# 50
# 28
# 61
# 70
# 65
# 59
# 88
# 54
# 76
# 87
# 43
# 10
# 73
# 48
# 88
# 62
# 70
# 98
# 82
# 64
# 54
# 33
# 78
# 85
# 78
# 70
# 54
# 58
# 62
# 66
# 55
# 76
# 77
# 76
# 66
# 60
# 88
# 39
# 62
# 54
# 83
# 68
# 81
# 77
# 51
# 70
# 58
# 80
# 84
# 78
# 67
# 52
# 69
# 63
# 84
# 53
# 43
# 66
# 27
# 60
# 69
# 32
# 58
# 70
# 100
# 45
# 43
# 67
# 63
# 55
# 56
# 79
# 93
# 67
# 62
# 50
# 69
# 85
# 74
# 62
# 91
# 38
# 85
# 56
# 74
# 76
# 76
# 54
# 94
# 79
# 43
# 47
# 83
# 64
# 33
# 70
# 80
# 100
# 78
# 64
# 58
# 78
# 62
# 54
# 54
# 62
# 81
# 90
# 79
# 68
# 58
# 69
# 60
# 71
# 87
# 68
# 44
# 78
# 81
# 86
# 64
# 58
# 87
# 70
# 88
# 84
# 80
# 57
# 73
# 56
# 59
# 65
# 64
# 72
# 79
# 55
# 43
# 57
# 82
# 77
# 61
# 70
# 73
# 81
# 75
# 40
# 68
# 93
# 82
# 52
# 70
# 81
# 57
# 89
# 46
# 36
# 64
# 87
# 61
# 71
# 74
# 73
# 38
# 79
# 41
# 100
# 84
# 72
# 66
# 55
# 46
# 65
# 71
# 51
# 57
# 60
# 73
# 72
# 53
# 75
# 60
# 61
# 23
# 45
# 83
# 76
# 74
# 65
# 86
# 44
# 39
# 67
# 46
# 80
# 72
# 57
# 54
# 66
# 68
# ...
